# %%
import mysql.connector

mydb = mysql.connector.connect(
    host='10.76.245.196',
    user='root',
    password='Password123!'
)
print(mydb)
mycursor = mydb.cursor()
mycursor.execute("SHOW DATABASES")
for i in mycursor:
    print(i)
# Out:
# <mysql.connector.connection_cext.CMySQLConnection object at 0x11268e050>
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('replicate1',)
# ('sys',)
# ('test',)

# %%
# !pip3 install mysql-connector-python

# %%
# !pip3 install pymango
