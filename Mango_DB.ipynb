# %%
# from pymongo import MongoClient
# client = MongoClient('10.76.245.178', 27017)
# db = client.admin
# collection = db.collection_name
# collection.find_one({"name":"name1"})

# %%
import pymongo
client = pymongo.MongoClient("10.76.245.178", 27017)
db = client.pwskills

# %%
coll_create= db["my_record"]

# %%
data = {
    "name": "prad",
    "class": "data science masters",
    "timing": "flexi"
}

# %%
coll_create.insert_one(data)
# Out:
# InsertOneResult(ObjectId('6624f621a08b5b3ba23ee4bc'), acknowledged=True)

# %%
data1 = {
    "mail_id": "abc@abc.com",
    "phone_number": 2345879080
}

# %%
coll_create.insert_one(data1)
# Out:
# InsertOneResult(ObjectId('6624f731a08b5b3ba23ee4bd'), acknowledged=True)

# %%
data2 = {
    "list_course": ["data science masters", "web dev", "java with dsa"],
    "mentor": ["Sudh", "Jack", "Allen"]
}

# %%
coll_create.insert_one(data2)
# Out:
# InsertOneResult(ObjectId('6624f7daa08b5b3ba23ee4be'), acknowledged=True)

# %%
for i in coll_create.find():
    print(i)
# Out:
# {'_id': ObjectId('6624f621a08b5b3ba23ee4bc'), 'name': 'prad', 'class': 'data science masters', 'timing': 'flexi'}
# {'_id': ObjectId('6624f731a08b5b3ba23ee4bd'), 'mail_id': 'abc@abc.com', 'phone_number': 2345879080}
# {'_id': ObjectId('6624f7daa08b5b3ba23ee4be'), 'list_course': ['data science masters', 'web dev', 'java with dsa'], 'mentor': ['Sudh', 'Jack', 'Allen']}

# %%
coll_create.find_one()
# Out:
# {'_id': ObjectId('6624f621a08b5b3ba23ee4bc'),
#  'name': 'prad',
#  'class': 'data science masters',
#  'timing': 'flexi'}

# %%
for i in coll_create.find({'name':'prad'}):
    print(i)
# Out:
# {'_id': ObjectId('6624f621a08b5b3ba23ee4bc'), 'name': 'prad', 'class': 'data science masters', 'timing': 'flexi'}
